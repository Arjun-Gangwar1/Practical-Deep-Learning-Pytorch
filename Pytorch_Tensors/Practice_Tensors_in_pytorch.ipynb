# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjun-Gangwar1/Practical-Deep-Learning-Pytorch/blob/main/Pytorch_Tensors/Practice_Tensors_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cpu

# %%
if torch.cuda.is_available():
  print()
